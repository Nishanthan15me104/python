# %%
# !pip install datasets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset


# Loading Dataset

data_set = load_dataset('lukebarousse/data_jobs')
df = data_set['train'].to_pandas()

#Data Clean Up
df.job_posted_date = pd.to_datetime(df.job_posted_date)

# %%
df.sample(10

)
# Out:
#               job_title_short  \
# 778056          Data Engineer
# 770327           Data Analyst
# 125428           Data Analyst
# 292344  Senior Data Scientist
# 406892          Data Engineer
# 218770      Software Engineer
# 502150           Data Analyst
# 510261          Data Engineer
# 86942          Data Scientist
# 574541           Data Analyst
#
#                                                 job_title     job_location  \
# 778056                                      Data Engineer   United Kingdom
# 770327                                       Data Analyst           Canada
# 125428                              Research Data Analyst         Maryland
# 292344               Senior Scientist, Data Science (JRD)    Cambridge, MA
# 406892                                Cloud Data Engineer        Leeds, UK
# 218770                              Senior System Analyst        Hong Kong
# 502150  Monitoring & Reporting Analyst (Social Inclusi...  Dublin, Ireland
# ...

# %%
df_india = df[df['job_country']=='India']

df_india.reset_index(inplace=True)

df_india.set_index('index',inplace=True)

# df_india.set_index('index')
df_india
# Out:
#              job_title_short  \
# index
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# index
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
median_pi = df.pivot_table(
    index='job_title_short',
    values=['salary_year_avg'],
    aggfunc=['median','min','max'])

# %%
#median_pi.sort_values(ascending=True,by='job_title_short',inplace=True)
median_pi
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Software Engineer                 99150.0         28000.0        375000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Business Analyst                  85000.0         16500.0        387460.0

# %%
median_pi.sort_index(ascending=False,inplace=True)
median_pi
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Software Engineer                 99150.0         28000.0        375000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Business Analyst                  85000.0         16500.0        387460.0
