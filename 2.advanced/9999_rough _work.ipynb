# %%
# !pip install datasets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset


# Loading Dataset

data_set = load_dataset('lukebarousse/data_jobs')
df = data_set['train'].to_pandas()

#Data Clean Up
df.job_posted_date = pd.to_datetime(df.job_posted_date)
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df.job_posted_date = pd.to_datetime(df.job_posted_date)
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

df_grouped = df.groupby('job_posted_month')

df_grouped

# month_dataframes = {}
# for month, group in df_grouped:
#     month_dataframes[month] = group

# %%
month_dataframes = {}
for month, group in df_grouped:
    month_dataframes[month] = group

# %%
pd.concat([month_dataframes['Jan'],month_dataframes['Feb'],month_dataframes['Mar']],ignore_index=True)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_da = df[(df['job_title_short'] == 'Data Scientist') & (df['job_country']== 'India')] 
ds_count = df_da['company_name'].value_counts()

ds_count.to_excel('companies to target',index=False,engine='openpyxl')

df_da
# Out:
#        job_title_short                                 job_title  \
# 19      Data Scientist                            Data Scientist
# 29      Data Scientist                            Data Scientist
# 239     Data Scientist  Power BI Data Analytics & Data Scientist
# 323     Data Scientist                       Forecasting Analyst
# 389     Data Scientist                            Data Scientist
# ...                ...                                       ...
# 785591  Data Scientist                         Data Scientist T8
# 785645  Data Scientist                       Data Science Intern
# 785654  Data Scientist                       Data Science Intern
# 785674  Data Scientist                            Data Scientist
# 785697  Data Scientist             Data Science Python modelling
#
#                        job_location          job_via job_schedule_type  \
# 19         Pune, Maharashtra, India       via Indeed         Full-time
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ds_count.to_excel('companies to target1.xlsx',index=True,engine='openpyxl')
