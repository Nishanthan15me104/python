# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ast
import seaborn as sns
from datasets import load_dataset
#hello


# Loading Dataset

data_set = load_dataset('lukebarousse/data_jobs')
df = data_set['train'].to_pandas()

#Data Clean Up
df.job_posted_date = pd.to_datetime(df.job_posted_date)

#convert job_skills to list
df['job_skills'] = df['job_skills'].apply(lambda skill_li: ast.literal_eval(skill_li) if pd.notna(skill_li) else skill_li)

# %%
df_da_us = df[(df['job_country'] == 'India') & (df['job_title_short'] == 'Data Scientist')].copy() #Filter country and job
df_da_us.head(2)
# Out:
#    job_title_short       job_title              job_location     job_via  \
# 19  Data Scientist  Data Scientist  Pune, Maharashtra, India  via Indeed
# 29  Data Scientist  Data Scientist  Pune, Maharashtra, India  via Exusia
#
#    job_schedule_type  job_work_from_home search_location     job_posted_date  \
# 19         Full-time               False           India 2023-04-26 13:20:12
# 29         Full-time               False           India 2023-03-26 13:16:20
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 19                  False                 False       India        None
# 29                  False                 False       India        None
#
#     salary_year_avg  salary_hour_avg       company_name  \
# 19              NaN              NaN  Bitwise Solutions
# 29              NaN              NaN             Exusia
#
#                                            job_skills  \
# 19  [r, sql, python, scala, java, c++, hadoop, tab...
# 29                                               None
#
#                                       job_type_skills
# 19  {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                               None

# %%
df_da_us['Job_posted_month_no'] = df_da_us['job_posted_date'].dt.month # to create a new column with number of month
df_da_us
# Out:
#        job_title_short                                 job_title  \
# 19      Data Scientist                            Data Scientist
# 29      Data Scientist                            Data Scientist
# 239     Data Scientist  Power BI Data Analytics & Data Scientist
# 323     Data Scientist                       Forecasting Analyst
# 389     Data Scientist                            Data Scientist
# ...                ...                                       ...
# 785591  Data Scientist                         Data Scientist T8
# 785645  Data Scientist                       Data Science Intern
# 785654  Data Scientist                       Data Science Intern
# 785674  Data Scientist                            Data Scientist
# 785697  Data Scientist             Data Science Python modelling
#
#                        job_location          job_via job_schedule_type  \
# 19         Pune, Maharashtra, India       via Indeed         Full-time
# 29         Pune, Maharashtra, India       via Exusia         Full-time
# 239              Maharashtra, India        via Shine         Full-time
# 323                        Anywhere     via LinkedIn         Full-time
# 389         New Delhi, Delhi, India     via LinkedIn        Contractor
# ...                             ...              ...               ...
# 785591  Bengaluru, Karnataka, India  via BeBee India         Full-time
# 785645                     Anywhere     via LinkedIn        Internship
# 785654                     Anywhere     via LinkedIn              None
# 785674  Kolkata, West Bengal, India     via LinkedIn         Full-time
# 785697     Pune, Maharashtra, India     via LinkedIn         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 19                   False           India 2023-04-26 13:20:12
# 29                   False           India 2023-03-26 13:16:20
# 239                  False           India 2023-11-11 13:10:08
# 323                   True           India 2023-09-28 13:48:45
# 389                  False           India 2023-09-12 13:16:27
# ...                    ...             ...                 ...
# 785591               False           India 2023-01-01 06:29:03
# 785645                True           India 2023-01-20 06:51:23
# 785654                True           India 2023-01-31 06:11:46
# 785674               False           India 2023-01-12 06:12:32
# 785697               False           India 2023-01-16 06:12:27
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 19                      False                 False       India        None
# 29                      False                 False       India        None
# 239                     False                 False       India        None
# 323                     False                 False       India        None
# 389                     False                 False       India        None
# ...                       ...                   ...         ...         ...
# 785591                  False                 False       India        None
# 785645                  False                 False       India        None
# 785654                  False                 False       India        None
# 785674                  False                 False       India        None
# 785697                  False                 False       India        None
#
#         salary_year_avg  salary_hour_avg  \
# 19                  NaN              NaN
# 29                  NaN              NaN
# 239                 NaN              NaN
# 323                 NaN              NaN
# 389                 NaN              NaN
# ...                 ...              ...
# 785591              NaN              NaN
# 785645              NaN              NaN
# 785654              NaN              NaN
# 785674              NaN              NaN
# 785697              NaN              NaN
#
#                                              company_name  \
# 19                                      Bitwise Solutions
# 29                                                 Exusia
# 239                                               Emerson
# 323                                               Straive
# 389                             Digital India Corporation
# ...                                                   ...
# 785591  Mercedes-Benz Research and Development India P...
# 785645                         TwiLearn EduTech Pvt. Ltd.
# 785654                                             Corizo
# 785674                        One Billion Ideas Pvt. LTD.
# 785697                                   Live Connections
#
#                                                job_skills  \
# 19      [r, sql, python, scala, java, c++, hadoop, tab...
# 29                                                   None
# 239                                            [power bi]
# 323                                               [excel]
# 389           [sql, sas, sas, excel, powerpoint, tableau]
# ...                                                   ...
# 785591  [java, python, aws, azure, kubernetes, docker,...
# 785645                                  [python, tableau]
# 785654                                             [zoom]
# 785674  [r, python, sql, scala, java, c++, matplotlib,...
# 785697  [python, sql, r, power bi, tableau, word, exce...
#
#                                           job_type_skills  Job_posted_month_no
# 19      {'analyst_tools': ['tableau'], 'libraries': ['...                    4
# 29                                                   None                    3
# 239                       {'analyst_tools': ['power bi']}                   11
# 323                          {'analyst_tools': ['excel']}                    9
# 389     {'analyst_tools': ['sas', 'excel', 'powerpoint...                    9
# ...                                                   ...                  ...
# 785591  {'async': ['jira', 'confluence'], 'cloud': ['a...                    1
# 785645  {'analyst_tools': ['tableau'], 'programming': ...                    1
# 785654                                 {'sync': ['zoom']}                    1
# 785674  {'analyst_tools': ['tableau'], 'libraries': ['...                    1
# 785697  {'analyst_tools': ['power bi', 'tableau', 'wor...                    1
#
# [13279 rows x 18 columns]

# %%
df_da_us_explode =df_da_us.explode('job_skills') # Exploded skills 
df_da_us
# Out:
#        job_title_short                                 job_title  \
# 19      Data Scientist                            Data Scientist
# 29      Data Scientist                            Data Scientist
# 239     Data Scientist  Power BI Data Analytics & Data Scientist
# 323     Data Scientist                       Forecasting Analyst
# 389     Data Scientist                            Data Scientist
# ...                ...                                       ...
# 785591  Data Scientist                         Data Scientist T8
# 785645  Data Scientist                       Data Science Intern
# 785654  Data Scientist                       Data Science Intern
# 785674  Data Scientist                            Data Scientist
# 785697  Data Scientist             Data Science Python modelling
#
#                        job_location          job_via job_schedule_type  \
# 19         Pune, Maharashtra, India       via Indeed         Full-time
# 29         Pune, Maharashtra, India       via Exusia         Full-time
# 239              Maharashtra, India        via Shine         Full-time
# 323                        Anywhere     via LinkedIn         Full-time
# 389         New Delhi, Delhi, India     via LinkedIn        Contractor
# ...                             ...              ...               ...
# 785591  Bengaluru, Karnataka, India  via BeBee India         Full-time
# 785645                     Anywhere     via LinkedIn        Internship
# 785654                     Anywhere     via LinkedIn              None
# 785674  Kolkata, West Bengal, India     via LinkedIn         Full-time
# 785697     Pune, Maharashtra, India     via LinkedIn         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 19                   False           India 2023-04-26 13:20:12
# 29                   False           India 2023-03-26 13:16:20
# 239                  False           India 2023-11-11 13:10:08
# 323                   True           India 2023-09-28 13:48:45
# 389                  False           India 2023-09-12 13:16:27
# ...                    ...             ...                 ...
# 785591               False           India 2023-01-01 06:29:03
# 785645                True           India 2023-01-20 06:51:23
# 785654                True           India 2023-01-31 06:11:46
# 785674               False           India 2023-01-12 06:12:32
# 785697               False           India 2023-01-16 06:12:27
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 19                      False                 False       India        None
# 29                      False                 False       India        None
# 239                     False                 False       India        None
# 323                     False                 False       India        None
# 389                     False                 False       India        None
# ...                       ...                   ...         ...         ...
# 785591                  False                 False       India        None
# 785645                  False                 False       India        None
# 785654                  False                 False       India        None
# 785674                  False                 False       India        None
# 785697                  False                 False       India        None
#
#         salary_year_avg  salary_hour_avg  \
# 19                  NaN              NaN
# 29                  NaN              NaN
# 239                 NaN              NaN
# 323                 NaN              NaN
# 389                 NaN              NaN
# ...                 ...              ...
# 785591              NaN              NaN
# 785645              NaN              NaN
# 785654              NaN              NaN
# 785674              NaN              NaN
# 785697              NaN              NaN
#
#                                              company_name  \
# 19                                      Bitwise Solutions
# 29                                                 Exusia
# 239                                               Emerson
# 323                                               Straive
# 389                             Digital India Corporation
# ...                                                   ...
# 785591  Mercedes-Benz Research and Development India P...
# 785645                         TwiLearn EduTech Pvt. Ltd.
# 785654                                             Corizo
# 785674                        One Billion Ideas Pvt. LTD.
# 785697                                   Live Connections
#
#                                                job_skills  \
# 19      [r, sql, python, scala, java, c++, hadoop, tab...
# 29                                                   None
# 239                                            [power bi]
# 323                                               [excel]
# 389           [sql, sas, sas, excel, powerpoint, tableau]
# ...                                                   ...
# 785591  [java, python, aws, azure, kubernetes, docker,...
# 785645                                  [python, tableau]
# 785654                                             [zoom]
# 785674  [r, python, sql, scala, java, c++, matplotlib,...
# 785697  [python, sql, r, power bi, tableau, word, exce...
#
#                                           job_type_skills  Job_posted_month_no
# 19      {'analyst_tools': ['tableau'], 'libraries': ['...                    4
# 29                                                   None                    3
# 239                       {'analyst_tools': ['power bi']}                   11
# 323                          {'analyst_tools': ['excel']}                    9
# 389     {'analyst_tools': ['sas', 'excel', 'powerpoint...                    9
# ...                                                   ...                  ...
# 785591  {'async': ['jira', 'confluence'], 'cloud': ['a...                    1
# 785645  {'analyst_tools': ['tableau'], 'programming': ...                    1
# 785654                                 {'sync': ['zoom']}                    1
# 785674  {'analyst_tools': ['tableau'], 'libraries': ['...                    1
# 785697  {'analyst_tools': ['power bi', 'tableau', 'wor...                    1
#
# [13279 rows x 18 columns]

# %%
# to create pivot table with month no. and skills list. 
df_da_us_pivot = df_da_us_explode.pivot_table(index='Job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

df_da_us_pivot.loc['Total'] = df_da_us_pivot.sum() #to calculate total of each skill

df_da_us_pivot
# Out:
# job_skills           airflow  alteryx  angular  angular.js  ansible  apl  \
# Job_posted_month_no
# 1                         31       21       11           0        5    0
# 2                         19       12        5           0        3    0
# 3                         26       13        2           0        4    0
# 4                         25       18        7           0        0    0
# 5                         22       22        6           0        0    0
# 6                         31       20        8           0        2    0
# 7                         25       36        6           0        1    4
# 8                         41       31        4           0        0    1
# 9                         18       19        5           1        0    0
# 10                        24       16        2           0        1    0
# 11                        40       29        6           0        0    0
# 12                        25       15        2           0        4    0
# Total                    327      252       64           1       20    5
#
# job_skills           arch  asana  asp.net  assembly  ...  vmware  vue  vue.js  \
# Job_posted_month_no                                  ...
# 1                       1      0        3         0  ...       0    1       1
# 2                       2      0        0         1  ...       0    0       0
# 3                       0      1        0         6  ...       1    0       0
# 4                       0      0        0         2  ...       2    0       0
# 5                       0      0        2         1  ...       1    0       0
# 6                       2      1        0         1  ...       1    0       0
# 7                       0      0        0         2  ...       0    1       0
# 8                       0      0        0         0  ...       0    0       0
# 9                       0      1        0         0  ...       2    2       0
# 10                      0      0        0         0  ...       0    0       0
# 11                      0      1        0         2  ...       1    1       1
# 12                      2      0        1         0  ...       1    0       0
# Total                   7      4        6        15  ...       9    5       2
#
# job_skills           watson  webex  windows  wire  word  yarn  zoom
# Job_posted_month_no
# 1                         5      1       15     0    30     3     2
# 2                         5      0        7     1    15     1     3
# 3                         5      0       10     0    20     0     4
# 4                         4      0        9     0    18     0     4
# 5                         2      0        7     0    21     0     3
# 6                         5      0       11     0    22     1     1
# 7                         3      0        7     0    31     2     1
# 8                         2      0        2     0    28     0     4
# 9                         0      0        3     1    25     1     2
# 10                        0      0        1     0    11     1     2
# 11                        0      1        7     0    31     0     4
# 12                        2      1       10     0    20     3     2
# Total                    33      3       89     2   272    12    32
#
# [13 rows x 200 columns]

# %%
# sns.heatmap(df_da_us_pivot, annot=True, cmap='Blues')  //check about heat map later
# plt.title('Job Skills Demand by Month')
# plt.show()


#// to Sort hte pivot table

df_da_us_pivot = df_da_us_pivot[df_da_us_pivot.loc['Total'].sort_values(ascending=False).index]



df_da_us_pivot = df_da_us_pivot.drop('Total') # after sorting to drop total row

df_da_us_pivot
# Out:
# job_skills           python  sql    r  aws  tableau  spark  tensorflow  azure  \
# Job_posted_month_no
# 1                       970  703  469  269      248    239         238    218
# 2                       608  425  285  149      164    154         147    120
# 3                       728  520  341  186      207    194         158    145
# 4                       645  465  317  192      183    181         172    142
# 5                       602  411  247  188      169    140         126    139
# 6                       842  561  388  218      192    212         212    164
# 7                       779  590  384  196      218    215         198    178
# 8                       794  563  394  222      239    241         213    190
# 9                       682  439  314  195      167    151         187    187
# 10                      626  405  296  182      157    164         175    148
# 11                     1145  751  519  353      278    290         308    284
# 12                      827  534  373  230      204    210         241    192
#
# job_skills           pytorch  hadoop  ...  delphi  nuix  clickup  next.js  \
# Job_posted_month_no                   ...
# 1                        140     194  ...       0     0        0        0
# 2                        112     121  ...       0     0        0        0
# 3                        127     145  ...       0     0        0        0
# 4                        130     132  ...       1     0        0        0
# 5                        103      95  ...       0     0        0        0
# 6                        158     155  ...       0     0        0        0
# 7                        152     167  ...       0     0        0        0
# 8                        156     176  ...       0     0        1        0
# 9                        148     124  ...       0     0        0        0
# 10                       143     141  ...       0     0        0        0
# 11                       253     197  ...       0     0        0        1
# 12                       195     131  ...       0     1        0        0
#
# job_skills           redhat  symphony  mlpack  codecommit  cobol  ringcentral
# Job_posted_month_no
# 1                         0         0       0           0      0            0
# 2                         0         0       0           0      0            0
# 3                         0         1       0           0      1            0
# 4                         0         0       0           1      0            0
# 5                         0         0       1           0      0            1
# 6                         0         0       0           0      0            0
# 7                         0         0       0           0      0            0
# 8                         0         0       0           0      0            0
# 9                         0         0       0           0      0            0
# 10                        0         0       0           0      0            0
# 11                        1         0       0           0      0            0
# 12                        0         0       0           0      0            0
#
# [12 rows x 200 columns]

# %%
da_total = df_da_us.groupby('Job_posted_month_no').size()
da_total
# Out:
# Job_posted_month_no
# 1     1444
# 2      932
# 3     1005
# 4      946
# 5      837
# 6     1129
# 7     1123
# 8     1157
# 9      984
# 10     902
# 11    1614
# 12    1206
# dtype: int64

# %%
df_da_per = df_da_us_pivot.div(da_total/100, axis=0)

df_da_per
# Out:
# job_skills              python        sql          r        aws    tableau  \
# Job_posted_month_no
# 1                    67.174515  48.684211  32.479224  18.628809  17.174515
# 2                    65.236052  45.600858  30.579399  15.987124  17.596567
# 3                    72.437811  51.741294  33.930348  18.507463  20.597015
# 4                    68.181818  49.154334  33.509514  20.295983  19.344609
# 5                    71.923536  49.103943  29.510155  22.461171  20.191159
# 6                    74.579274  49.689991  34.366696  19.309123  17.006200
# 7                    69.367765  52.537845  34.194123  17.453250  19.412289
# 8                    68.625756  48.660328  34.053587  19.187554  20.656871
# 9                    69.308943  44.613821  31.910569  19.817073  16.971545
# 10                   69.401330  44.900222  32.815965  20.177384  17.405765
# 11                   70.941760  46.530359  32.156134  21.871128  17.224287
# 12                   68.573798  44.278607  30.928690  19.071310  16.915423
#
# job_skills               spark  tensorflow      azure    pytorch     hadoop  \
# Job_posted_month_no
# 1                    16.551247   16.481994  15.096953   9.695291  13.434903
# 2                    16.523605   15.772532  12.875536  12.017167  12.982833
# 3                    19.303483   15.721393  14.427861  12.636816  14.427861
# 4                    19.133192   18.181818  15.010571  13.742072  13.953488
# 5                    16.726404   15.053763  16.606930  12.305854  11.350060
# 6                    18.777679   18.777679  14.526129  13.994686  13.728964
# 7                    19.145147   17.631345  15.850401  13.535174  14.870882
# 8                    20.829732   18.409680  16.421780  13.483146  15.211755
# 9                    15.345528   19.004065  19.004065  15.040650  12.601626
# 10                   18.181818   19.401330  16.407982  15.853659  15.631929
# 11                   17.967782   19.083024  17.596035  15.675341  12.205700
# 12                   17.412935   19.983416  15.920398  16.169154  10.862355
#
# job_skills           ...    delphi      nuix  clickup   next.js    redhat  \
# Job_posted_month_no  ...
# 1                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 2                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 3                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 4                    ...  0.105708  0.000000  0.00000  0.000000  0.000000
# 5                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 6                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 7                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 8                    ...  0.000000  0.000000  0.08643  0.000000  0.000000
# 9                    ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 10                   ...  0.000000  0.000000  0.00000  0.000000  0.000000
# 11                   ...  0.000000  0.000000  0.00000  0.061958  0.061958
# 12                   ...  0.000000  0.082919  0.00000  0.000000  0.000000
#
# job_skills           symphony    mlpack  codecommit     cobol  ringcentral
# Job_posted_month_no
# 1                    0.000000  0.000000    0.000000  0.000000     0.000000
# 2                    0.000000  0.000000    0.000000  0.000000     0.000000
# 3                    0.099502  0.000000    0.000000  0.099502     0.000000
# 4                    0.000000  0.000000    0.105708  0.000000     0.000000
# 5                    0.000000  0.119474    0.000000  0.000000     0.119474
# 6                    0.000000  0.000000    0.000000  0.000000     0.000000
# 7                    0.000000  0.000000    0.000000  0.000000     0.000000
# 8                    0.000000  0.000000    0.000000  0.000000     0.000000
# 9                    0.000000  0.000000    0.000000  0.000000     0.000000
# 10                   0.000000  0.000000    0.000000  0.000000     0.000000
# 11                   0.000000  0.000000    0.000000  0.000000     0.000000
# 12                   0.000000  0.000000    0.000000  0.000000     0.000000
#
# [12 rows x 200 columns]

# %%
df_da_per =df_da_per.reset_index()

df_da_per['job_posted_month'] = pd.to_datetime(df_da_per['Job_posted_month_no'], format='%m').dt.strftime('%B')

df_da_per = df_da_per.set_index('job_posted_month')

df_da_per = df_da_per.drop(columns='Job_posted_month_no')
df_da_per
# Out:
# job_skills           python        sql          r        aws    tableau  \
# job_posted_month
# January           67.174515  48.684211  32.479224  18.628809  17.174515
# February          65.236052  45.600858  30.579399  15.987124  17.596567
# March             72.437811  51.741294  33.930348  18.507463  20.597015
# April             68.181818  49.154334  33.509514  20.295983  19.344609
# May               71.923536  49.103943  29.510155  22.461171  20.191159
# June              74.579274  49.689991  34.366696  19.309123  17.006200
# July              69.367765  52.537845  34.194123  17.453250  19.412289
# August            68.625756  48.660328  34.053587  19.187554  20.656871
# September         69.308943  44.613821  31.910569  19.817073  16.971545
# October           69.401330  44.900222  32.815965  20.177384  17.405765
# November          70.941760  46.530359  32.156134  21.871128  17.224287
# December          68.573798  44.278607  30.928690  19.071310  16.915423
#
# job_skills            spark  tensorflow      azure    pytorch     hadoop  ...  \
# job_posted_month                                                          ...
# January           16.551247   16.481994  15.096953   9.695291  13.434903  ...
# February          16.523605   15.772532  12.875536  12.017167  12.982833  ...
# March             19.303483   15.721393  14.427861  12.636816  14.427861  ...
# April             19.133192   18.181818  15.010571  13.742072  13.953488  ...
# May               16.726404   15.053763  16.606930  12.305854  11.350060  ...
# June              18.777679   18.777679  14.526129  13.994686  13.728964  ...
# July              19.145147   17.631345  15.850401  13.535174  14.870882  ...
# August            20.829732   18.409680  16.421780  13.483146  15.211755  ...
# September         15.345528   19.004065  19.004065  15.040650  12.601626  ...
# October           18.181818   19.401330  16.407982  15.853659  15.631929  ...
# November          17.967782   19.083024  17.596035  15.675341  12.205700  ...
# December          17.412935   19.983416  15.920398  16.169154  10.862355  ...
#
# job_skills          delphi      nuix  clickup   next.js    redhat  symphony  \
# job_posted_month
# January           0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# February          0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# March             0.000000  0.000000  0.00000  0.000000  0.000000  0.099502
# April             0.105708  0.000000  0.00000  0.000000  0.000000  0.000000
# May               0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# June              0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# July              0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# August            0.000000  0.000000  0.08643  0.000000  0.000000  0.000000
# September         0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# October           0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# November          0.000000  0.000000  0.00000  0.061958  0.061958  0.000000
# December          0.000000  0.082919  0.00000  0.000000  0.000000  0.000000
#
# job_skills          mlpack  codecommit     cobol  ringcentral
# job_posted_month
# January           0.000000    0.000000  0.000000     0.000000
# February          0.000000    0.000000  0.000000     0.000000
# March             0.000000    0.000000  0.099502     0.000000
# April             0.000000    0.105708  0.000000     0.000000
# May               0.119474    0.000000  0.000000     0.119474
# June              0.000000    0.000000  0.000000     0.000000
# July              0.000000    0.000000  0.000000     0.000000
# August            0.000000    0.000000  0.000000     0.000000
# September         0.000000    0.000000  0.000000     0.000000
# October           0.000000    0.000000  0.000000     0.000000
# November          0.000000    0.000000  0.000000     0.000000
# December          0.000000    0.000000  0.000000     0.000000
#
# [12 rows x 200 columns]

# %%
df_plot = df_da_per.iloc[:, :5]

sns.lineplot(data=df_plot, dashes=False, palette='tab10')

sns.set_theme(style='dark')
sns.despine()
plt.legend().set_visible(False)
plt.title('Trending top for Data Scientist in India')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

for i in range(5):
    plt.text(11.2,df_plot.iloc[-1, i], df_plot.columns[i])
